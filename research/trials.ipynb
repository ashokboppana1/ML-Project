# %%
import os

# %%
d={
"key1":"value1",
"key2":"value2"


}

# %%
d['key1']
# Out:
# 'value1'

# %%
d.values
# Out:
# <function dict.values>

# %%
d.items
# Out:
# <function dict.items>

# %%
pip install python-box
# Out:
# ...
#   Using cached python_box-7.3.2-cp311-cp311-win_amd64.whl.metadata (8.3 kB)
# Using cached python_box-7.3.2-cp311-cp311-win_amd64.whl (1.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from box  import ConfigBox
d1=ConfigBox({"key1":"value1",
"key2":"value2"})

# %%
d1.key1
# Out:
# 'value1'

# %%
###ensure annotation

def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(4,"5")
# Out:
# '5555'

# %%
pip install ensure
# Out:
# ...
#   Using cached ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached ensure-1.0.4-py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_productmul(x:int,y:int)->int:
    return x*y

# %%
get_productmul(3,4)
# Out:
# 12
